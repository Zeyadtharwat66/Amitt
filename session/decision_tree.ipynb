# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

dataset_path=(r'C:\D\Amitt\session\Position_Salaries.csv')
datasets=pd.read_csv(dataset_path)

datasets.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
x=datasets.iloc[:,1:2].values
y=datasets.iloc[:,2].values

# %%
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
value_to_predict=6.5
y_pred=regressor.predict([[value_to_predict]])
y_pred[0]
# Out:
# np.float64(150000.0)

# %%
x_grid=np.arange(min(x),max(x),0.01)
x_grid=x_grid.reshape(len(x_grid),1)
plt.scatter(x,y,color='red',label='Actual data')
plt.plot(x_grid,regressor.predict(x_grid),color='blue',label='Regression Curve')
plt.title('decision tree regression results')
plt.xlabel('position level')
plt.ylabel('salary')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_5740\3573839619.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid=np.arange(min(x),max(x),0.01)
