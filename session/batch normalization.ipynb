# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from tensorflow import keras

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
dataset.drop('Geography',axis=1,inplace=True)
dataset.drop('Gender',axis=1,inplace=True)
X = dataset.iloc[:, 3:11].values
y = dataset.iloc[:, 11].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(6, activation="relu",input_dim = 8),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(6, activation="relu"),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 6)                 54
#
#  batch_normalization_8 (Batc  (None, 6)                24
#  hNormalization)
#
#  dense_15 (Dense)            (None, 6)                 42
#
#  batch_normalization_9 (Batc  (None, 6)                24
#  hNormalization)
#
#  dense_16 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 151
# Trainable params: 127
# Non-trainable params: 24
# _________________________________________________________________

# %%
model.compile(optimizer = 'SGD', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 5s 7ms/step - loss: 0.6033 - accuracy: 0.6646
# Epoch 2/100
# 250/250 [==============================] - 2s 6ms/step - loss: 0.4846 - accuracy: 0.8025
# Epoch 3/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4612 - accuracy: 0.8048
# Epoch 4/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4520 - accuracy: 0.8095
# Epoch 5/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4431 - accuracy: 0.8099
# Epoch 6/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4392 - accuracy: 0.8148
# Epoch 7/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4353 - accuracy: 0.8151
# Epoch 8/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4322 - accuracy: 0.8175
# Epoch 9/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4295 - accuracy: 0.8215
# Epoch 10/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4270 - accuracy: 0.8200
# Epoch 11/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4262 - accuracy: 0.8204
# Epoch 12/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4241 - accuracy: 0.8219
# Epoch 13/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4212 - accuracy: 0.8217
# Epoch 14/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4217 - accuracy: 0.8206
# Epoch 15/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.4177 - accuracy: 0.8209
# Epoch 16/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.4169 - accuracy: 0.8221
# Epoch 17/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4146 - accuracy: 0.8223
# Epoch 18/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4109 - accuracy: 0.8219
# Epoch 19/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4091 - accuracy: 0.8240
# Epoch 20/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4062 - accuracy: 0.8226
# Epoch 21/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.4026 - accuracy: 0.8240
# Epoch 22/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.4014 - accuracy: 0.8236
# Epoch 23/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3970 - accuracy: 0.8267
# Epoch 24/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3966 - accuracy: 0.8335
# Epoch 25/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3937 - accuracy: 0.8355
# Epoch 26/100
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3905 - accuracy: 0.8354
# Epoch 27/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3897 - accuracy: 0.8394
# Epoch 28/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3881 - accuracy: 0.8446
# Epoch 29/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3861 - accuracy: 0.8406
# Epoch 30/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3824 - accuracy: 0.8466
# Epoch 31/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3828 - accuracy: 0.8426
# Epoch 32/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3768 - accuracy: 0.8470
# Epoch 33/100
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3810 - accuracy: 0.8455
# Epoch 34/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3774 - accuracy: 0.8455
# Epoch 35/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3784 - accuracy: 0.8457
# Epoch 36/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3745 - accuracy: 0.8494
# Epoch 37/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3763 - accuracy: 0.8457
# Epoch 38/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3748 - accuracy: 0.8465
# Epoch 39/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3750 - accuracy: 0.8493
# Epoch 40/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3733 - accuracy: 0.8474
# Epoch 41/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3737 - accuracy: 0.8469
# Epoch 42/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3771 - accuracy: 0.8478
# Epoch 43/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3698 - accuracy: 0.8497
# Epoch 44/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3763 - accuracy: 0.8497
# Epoch 45/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3720 - accuracy: 0.8494
# Epoch 46/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3730 - accuracy: 0.8489
# Epoch 47/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3706 - accuracy: 0.8494
# Epoch 48/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3735 - accuracy: 0.8489
# Epoch 49/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3687 - accuracy: 0.8490
# Epoch 50/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3721 - accuracy: 0.8451
# Epoch 51/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3720 - accuracy: 0.8481
# Epoch 52/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3701 - accuracy: 0.8509
# Epoch 53/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3713 - accuracy: 0.8496
# Epoch 54/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3737 - accuracy: 0.8489
# Epoch 55/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3680 - accuracy: 0.8474
# Epoch 56/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3709 - accuracy: 0.8518
# Epoch 57/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3674 - accuracy: 0.8510
# Epoch 58/100
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3700 - accuracy: 0.8493
# Epoch 59/100
# 250/250 [==============================] - 1s 6ms/step - loss: 0.3701 - accuracy: 0.8510
# Epoch 60/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3670 - accuracy: 0.8504
# Epoch 61/100
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3682 - accuracy: 0.8495
# Epoch 62/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3674 - accuracy: 0.8519
# Epoch 63/100
# 250/250 [==============================] - 2s 9ms/step - loss: 0.3688 - accuracy: 0.8484
# Epoch 64/100
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3626 - accuracy: 0.8521
# Epoch 65/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3647 - accuracy: 0.8519
# Epoch 66/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3635 - accuracy: 0.8519
# Epoch 67/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3678 - accuracy: 0.8486
# Epoch 68/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3647 - accuracy: 0.8508
# Epoch 69/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3670 - accuracy: 0.8512
# Epoch 70/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3645 - accuracy: 0.8499
# Epoch 71/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3655 - accuracy: 0.8514
# Epoch 72/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3652 - accuracy: 0.8510
# Epoch 73/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3616 - accuracy: 0.8528
# Epoch 74/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3646 - accuracy: 0.8500
# Epoch 75/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3663 - accuracy: 0.8510
# Epoch 76/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3620 - accuracy: 0.8516
# Epoch 77/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3629 - accuracy: 0.8528
# Epoch 78/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8496
# Epoch 79/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8524
# Epoch 80/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3641 - accuracy: 0.8520
# Epoch 81/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3634 - accuracy: 0.8524
# Epoch 82/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8520
# Epoch 83/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3641 - accuracy: 0.8490
# Epoch 84/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3644 - accuracy: 0.8520
# Epoch 85/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3630 - accuracy: 0.8521
# Epoch 86/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3641 - accuracy: 0.8515
# Epoch 87/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3629 - accuracy: 0.8547
# Epoch 88/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3648 - accuracy: 0.8482
# Epoch 89/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3679 - accuracy: 0.8516
# Epoch 90/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3622 - accuracy: 0.8565
# Epoch 91/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3618 - accuracy: 0.8509
# Epoch 92/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3637 - accuracy: 0.8519
# Epoch 93/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3645 - accuracy: 0.8512
# Epoch 94/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8493
# Epoch 95/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3642 - accuracy: 0.8536
# Epoch 96/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8545
# Epoch 97/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3590 - accuracy: 0.8518
# Epoch 98/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3629 - accuracy: 0.8512
# Epoch 99/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3630 - accuracy: 0.8520
# Epoch 100/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3606 - accuracy: 0.8519

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
mnist = keras.datasets.mnist
mnist
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#       3 import numpy as np
#
# File c:\Program Files\Python311\Lib\site-packages\tensorflow\__init__.py:467
#     465     importlib.import_module("tf_keras.src.optimizers")
#     466   else:
# --> 467     importlib.import_module("keras.src.optimizers")
#     468 except (ImportError, AttributeError):
#     469   pass
#
# File c:\Program Files\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Program Files\Python311\Lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# File c:\Program Files\Python311\Lib\site-packages\keras\api\__init__.py:35
#      33 from keras.api import utils
#      34 from keras.api import visualization
# ---> 35 from keras.api import wrappers
#      36 from keras.src.backend import Variable
#      37 from keras.src.backend import device
#
# File c:\Program Files\Python311\Lib\site-packages\keras\api\wrappers\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.wrappers.sklearn_wrapper import SKLearnClassifier
#       8 from keras.src.wrappers.sklearn_wrapper import SKLearnRegressor
#       9 from keras.src.wrappers.sklearn_wrapper import SKLearnTransformer
#
# File c:\Program Files\Python311\Lib\site-packages\keras\src\wrappers\__init__.py:1
# ----> 1 from keras.src.wrappers.sklearn_wrapper import SKLearnClassifier
#       2 from keras.src.wrappers.sklearn_wrapper import SKLearnRegressor
#       3 from keras.src.wrappers.sklearn_wrapper import SKLearnTransformer
#
# File c:\Program Files\Python311\Lib\site-packages\keras\src\wrappers\sklearn_wrapper.py:8
#       6 from keras.src.models.cloning import clone_model
#       7 from keras.src.models.model import Model
# ----> 8 from keras.src.wrappers.fixes import _routing_enabled
#       9 from keras.src.wrappers.fixes import _validate_data
#      10 from keras.src.wrappers.fixes import type_of_target
#
# File c:\Program Files\Python311\Lib\site-packages\keras\src\wrappers\fixes.py:2
#       1 try:
# ----> 2     import sklearn
#       3 except ImportError:
#       4     sklearn = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      76 _submodules = [
#      77     "calibration",
#      78     "cluster",
#    (...)
#     114     "compose",
#     115 ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\__init__.py:15
#      13 from . import _joblib, metadata_routing
#      14 from ._bunch import Bunch
# ---> 15 from ._chunking import gen_batches, gen_even_slices
#      16 from ._estimator_html_repr import estimator_html_repr
#      18 # Make _safe_indexing importable from here for backward compat as this particular
#      19 # helper is considered semi-private and typically very useful for third-party
#      20 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      21 # _safe_indexing was included in our public API documentation despite the leading
#      22 # `_` in its name.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from .._config import config_context, get_config
# ---> 17 from .validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:21
#      19 from .. import get_config as _get_config
#      20 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 21 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      22 from ..utils.deprecation import _deprecate_force_all_finite
#      23 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_array_api.py:17
#      14 import scipy.special as special
#      16 from .._config import get_config
# ---> 17 from .fixes import parse_version
#      19 _NUMPY_NAMESPACE_NAMES = {"numpy", "array_api_compat.numpy"}
#      22 def yield_namespaces(include_numpy_namespaces=True):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\fixes.py:17
#      15 import scipy
#      16 import scipy.sparse.linalg
# ---> 17 import scipy.stats
#      19 try:
#      20     import pandas as pd
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\stats\__init__.py:624
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     619
#     620 """  # noqa: E501
#     622 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     623                                DegenerateDataWarning, FitError)
# --> 624 from ._stats_py import *
#     625 from ._variation import variation
#     626 from .distributions import *
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_stats_py.py:52
#      49 # Import unused here but needs to stay until end of deprecation periode
#      50 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      51 from scipy import linalg  # noqa: F401
# ---> 52 from . import distributions
#      53 from . import _mstats_basic as mstats_basic
#      55 from ._stats_mstats_common import _find_repeats, theilslopes, siegelslopes
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\stats\distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File ~\AppData\Roaming\Python\Python311\site-packages\scipy\stats\_continuous_distns.py:24
#      21 import scipy.special._ufuncs as scu
#      22 from scipy._lib._util import _lazyselect, _lazywhere
# ---> 24 from . import _stats
#      25 from ._tukeylambda_stats import (tukeylambda_variance as _tlvar,
#      26                                  tukeylambda_kurtosis as _tlkurt)
#      27 from ._distn_infrastructure import (_vectorize_rvs_over_shapes,
#      28     get_distribution_names, _kurtosis, _isintegral,
#      29     rv_continuous, _skew, _get_fixed_fit_value, _check_shape, _ShapeInfo)
#
# File <frozen importlib._bootstrap>:405, in parent(self)
#
# KeyboardInterrupt:
